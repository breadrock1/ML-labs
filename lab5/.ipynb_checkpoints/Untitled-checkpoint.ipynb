# %% [markdown]
# # Neural networks

# %% [markdown]
# Collect a set of photos of your team members. Train the neuron so that she will classify the new photos of the participants well.

# %% [markdown]
# ## Import libs and load dataset

# %%
import numpy as np
np.random.seed(123)

import mtcnn
print(mtcnn.__version__)

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Convolution2D, MaxPooling2D
from keras.utils import np_utils
from keras.applications import VGG19, imagenet_utils
from keras.preprocessing.image import img_to_array, ImageDataGenerator
# Out:
# 0.1.0

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3222536188625654794
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9762781874460421384
# physical_device_desc: "device: XLA_CPU device"
# ]

# %% [markdown]
# ## Experimental examples

# %% [markdown]
# ### Import addition libs

# %%
from PIL import Image
from matplotlib import pyplot
from mtcnn.mtcnn import MTCNN

# %% [markdown]
# ### Formating image

# %%
def extract_face(filename, required_size=(224, 224), resize=False):
    pixels = pyplot.imread(filename)
    detector = MTCNN()
    results = detector.detect_faces(pixels)
    x1, y1, width, height = results[0]['box']
    x2, y2 = x1 + width, y1 + height
    face = pixels[y1:y2, x1:x2]
    image = Image.fromarray(face)
    if resize: image = image.resize(required_size)
    face_array = np.asarray(image)
    return face_array

def print_image(img):
    if isinstance(img, str): img = pyplot.imread(img)
    pyplot.imshow(img)
    pyplot.show()

# %% [markdown]
# ### Example 1

# %%
print_image("l5_face_rec/don_korleon/1.jpg")

# %%
print_image(extract_face("l5_face_rec/don_korleon/1.jpg"))

# %% [markdown]
# ### Example 2

# %%
print_image("l5_face_rec/sex_king/1.jpg")

# %%
print_image(extract_face("l5_face_rec/sex_king/1.jpg"))

# %% [markdown]
# ## Face recognition

# %% [markdown]
# ### Preparation

# %%
from keras.models import Sequential
from keras.layers import ZeroPadding2D, Convolution2D, MaxPooling2D, Dropout, Flatten, Activation, Dense

# %%
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(224,224, 3)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(Convolution2D(4096, (7, 7), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(4096, (1, 1), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(2622, (1, 1)))
model.add(Flatten())
model.add(Activation('softmax'))

# %%
from keras.models import model_from_json
model.load_weights('l5_dataset/vgg_face_weights.h5')

# %%
final_layer = Dense(2, activation='softmax')(model.layers[-2].output)
from keras.models import Model
model = Model(model.inputs, final_layer)
for layer in model.layers[:-1]:
    layer.trainable = False

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Learning

# %%
import os
dir1 = "l5_dataset/student_of_daunka_1/"
dir2 = "l5_dataset/student_of_daunka_2/"
files1 = os.listdir(dir1)
files2 = os.listdir(dir2)

# %%
images1 = [extract_face(os.path.join(dir1, i), resize=True) for i in files1]
images2 = [extract_face(os.path.join(dir2, i), resize=True) for i in files2]

# %%
X_train = images1[:-2] + images2[:-2]
y_train = [[1, 0]] * len(images1[:-2]) + [[0, 1]] * len(images2[:-2])

X_test = images1[-2:]  + images2[-2:]
y_test = [[1, 0], [1, 0], [0, 1], [0, 1]]

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1. / 255)
train = train_datagen.flow(np.asarray(X_train), np.asarray(y_train))

# %%
model.fit_generator(train, epochs=100, verbose=2)
model.save_weights("l5_face_rec_model_weights.h5")
model.load_weights("l5_face_rec_model_weights.h5")
# Out:
# Epoch 1/100
#  - 3s - loss: 0.6928 - accuracy: 0.3333
# Epoch 2/100
#  - 3s - loss: 0.6875 - accuracy: 0.5833
# Epoch 3/100
#  - 3s - loss: 0.6833 - accuracy: 0.8333
# Epoch 4/100
#  - 3s - loss: 0.6692 - accuracy: 1.0000
# Epoch 5/100
#  - 3s - loss: 0.6682 - accuracy: 0.8333
# Epoch 6/100
#  - 3s - loss: 0.6577 - accuracy: 1.0000
# Epoch 7/100
#  - 3s - loss: 0.6522 - accuracy: 0.9167
# Epoch 8/100
#  - 3s - loss: 0.6453 - accuracy: 0.9167
# Epoch 9/100
#  - 3s - loss: 0.6443 - accuracy: 0.9167
# Epoch 10/100
#  - 3s - loss: 0.6346 - accuracy: 1.0000
# Epoch 11/100
#  - 3s - loss: 0.6278 - accuracy: 1.0000
# Epoch 12/100
#  - 3s - loss: 0.6174 - accuracy: 1.0000
# Epoch 13/100
#  - 3s - loss: 0.6122 - accuracy: 1.0000
# Epoch 14/100
#  - 3s - loss: 0.6221 - accuracy: 1.0000
# Epoch 15/100
#  - 3s - loss: 0.6005 - accuracy: 1.0000
# Epoch 16/100
#  - 3s - loss: 0.5887 - accuracy: 0.9167
# Epoch 17/100
#  - 3s - loss: 0.5788 - accuracy: 1.0000
# Epoch 18/100
#  - 3s - loss: 0.5784 - accuracy: 1.0000
# Epoch 19/100
#  - 3s - loss: 0.5717 - accuracy: 1.0000
# Epoch 20/100
#  - 3s - loss: 0.5889 - accuracy: 1.0000
# Epoch 21/100
#  - 3s - loss: 0.5594 - accuracy: 1.0000
# Epoch 22/100
#  - 3s - loss: 0.5564 - accuracy: 1.0000
# Epoch 23/100
#  - 3s - loss: 0.5531 - accuracy: 1.0000
# Epoch 24/100
#  - 3s - loss: 0.5431 - accuracy: 1.0000
# Epoch 25/100
#  - 3s - loss: 0.5618 - accuracy: 1.0000
# Epoch 26/100
#  - 3s - loss: 0.5379 - accuracy: 1.0000
# Epoch 27/100
#  - 3s - loss: 0.5325 - accuracy: 1.0000
# Epoch 28/100
#  - 3s - loss: 0.5245 - accuracy: 1.0000
# Epoch 29/100
#  - 3s - loss: 0.5033 - accuracy: 1.0000
# Epoch 30/100
#  - 3s - loss: 0.5428 - accuracy: 1.0000
# Epoch 31/100
#  - 3s - loss: 0.5188 - accuracy: 1.0000
# Epoch 32/100
#  - 3s - loss: 0.5057 - accuracy: 1.0000
# Epoch 33/100
#  - 3s - loss: 0.4943 - accuracy: 1.0000
# Epoch 34/100
#  - 3s - loss: 0.5499 - accuracy: 1.0000
# Epoch 35/100
#  - 3s - loss: 0.4742 - accuracy: 1.0000
# Epoch 36/100
#  - 3s - loss: 0.4898 - accuracy: 1.0000
# Epoch 37/100
#  - 3s - loss: 0.4795 - accuracy: 1.0000
# Epoch 38/100
#  - 3s - loss: 0.4667 - accuracy: 1.0000
# Epoch 39/100
#  - 3s - loss: 0.4901 - accuracy: 1.0000
# Epoch 40/100
#  - 3s - loss: 0.4784 - accuracy: 1.0000
# Epoch 41/100
#  - 3s - loss: 0.4679 - accuracy: 1.0000
# Epoch 42/100
#  - 3s - loss: 0.4746 - accuracy: 1.0000
# Epoch 43/100
#  - 3s - loss: 0.4724 - accuracy: 1.0000
# Epoch 44/100
#  - 3s - loss: 0.4398 - accuracy: 1.0000
# Epoch 45/100
#  - 3s - loss: 0.4442 - accuracy: 1.0000
# Epoch 46/100
#  - 3s - loss: 0.4431 - accuracy: 1.0000
# Epoch 47/100
#  - 3s - loss: 0.4274 - accuracy: 1.0000
# Epoch 48/100
#  - 3s - loss: 0.4268 - accuracy: 1.0000
# Epoch 49/100
#  - 3s - loss: 0.4148 - accuracy: 1.0000
# Epoch 50/100
#  - 3s - loss: 0.4634 - accuracy: 1.0000
# Epoch 51/100
#  - 3s - loss: 0.4325 - accuracy: 1.0000
# Epoch 52/100
#  - 3s - loss: 0.4367 - accuracy: 1.0000
# Epoch 53/100
#  - 3s - loss: 0.4119 - accuracy: 1.0000
# Epoch 54/100
#  - 3s - loss: 0.4271 - accuracy: 1.0000
# Epoch 55/100
#  - 3s - loss: 0.4029 - accuracy: 1.0000
# Epoch 56/100
#  - 3s - loss: 0.4033 - accuracy: 1.0000
# Epoch 57/100
#  - 3s - loss: 0.3662 - accuracy: 1.0000
# Epoch 58/100
#  - 3s - loss: 0.3660 - accuracy: 1.0000
# Epoch 59/100
#  - 3s - loss: 0.4132 - accuracy: 1.0000
# Epoch 60/100
#  - 3s - loss: 0.3671 - accuracy: 1.0000
# Epoch 61/100
#  - 3s - loss: 0.4138 - accuracy: 1.0000
# Epoch 62/100
#  - 3s - loss: 0.4105 - accuracy: 1.0000
# Epoch 63/100
#  - 3s - loss: 0.3611 - accuracy: 1.0000
# Epoch 64/100
#  - 3s - loss: 0.3639 - accuracy: 1.0000
# Epoch 65/100
#  - 3s - loss: 0.3721 - accuracy: 1.0000
# Epoch 66/100
#  - 3s - loss: 0.3441 - accuracy: 1.0000
# Epoch 67/100
#  - 3s - loss: 0.3539 - accuracy: 1.0000
# Epoch 68/100
#  - 3s - loss: 0.3802 - accuracy: 1.0000
# Epoch 69/100
#  - 3s - loss: 0.3849 - accuracy: 1.0000
# Epoch 70/100
#  - 3s - loss: 0.3617 - accuracy: 1.0000
# Epoch 71/100
#  - 3s - loss: 0.3576 - accuracy: 1.0000
# Epoch 72/100
#  - 3s - loss: 0.3400 - accuracy: 1.0000
# Epoch 73/100
#  - 3s - loss: 0.3325 - accuracy: 1.0000
# Epoch 74/100
#  - 3s - loss: 0.3302 - accuracy: 1.0000
# Epoch 75/100
#  - 3s - loss: 0.3603 - accuracy: 1.0000
# Epoch 76/100
#  - 3s - loss: 0.3544 - accuracy: 1.0000
# Epoch 77/100
#  - 3s - loss: 0.3483 - accuracy: 1.0000
# Epoch 78/100
#  - 3s - loss: 0.3201 - accuracy: 1.0000
# Epoch 79/100
#  - 3s - loss: 0.2988 - accuracy: 1.0000
# Epoch 80/100
#  - 3s - loss: 0.3092 - accuracy: 1.0000
# Epoch 81/100
#  - 3s - loss: 0.2949 - accuracy: 1.0000
# Epoch 82/100
#  - 3s - loss: 0.3084 - accuracy: 1.0000
# Epoch 83/100
#  - 3s - loss: 0.3432 - accuracy: 1.0000
# Epoch 84/100
#  - 3s - loss: 0.3652 - accuracy: 1.0000
# Epoch 85/100
#  - 3s - loss: 0.2985 - accuracy: 1.0000
# Epoch 86/100
#  - 3s - loss: 0.2539 - accuracy: 1.0000
# Epoch 87/100
#  - 3s - loss: 0.2991 - accuracy: 1.0000
# Epoch 88/100
#  - 3s - loss: 0.2655 - accuracy: 1.0000
# Epoch 89/100
#  - 3s - loss: 0.3267 - accuracy: 1.0000
# Epoch 90/100
#  - 3s - loss: 0.3055 - accuracy: 1.0000
# Epoch 91/100
#  - 3s - loss: 0.2766 - accuracy: 1.0000
# Epoch 92/100
#  - 3s - loss: 0.2626 - accuracy: 1.0000
# Epoch 93/100
#  - 3s - loss: 0.2845 - accuracy: 1.0000
# Epoch 94/100
#  - 3s - loss: 0.3148 - accuracy: 1.0000
# Epoch 95/100
#  - 3s - loss: 0.3029 - accuracy: 1.0000
# Epoch 96/100
#  - 3s - loss: 0.2859 - accuracy: 1.0000
# Epoch 97/100
#  - 3s - loss: 0.2790 - accuracy: 1.0000
# Epoch 98/100
#  - 3s - loss: 0.2948 - accuracy: 1.0000
# Epoch 99/100
#  - 3s - loss: 0.2812 - accuracy: 1.0000
# Epoch 100/100
#  - 3s - loss: 0.2783 - accuracy: 1.0000

# %% [markdown]
# ### Check results of learning

# %%
model.predict(np.asarray(X_test))
# Out:
# array([[1., 0.],
#        [1., 0.],
#        [0., 1.],
#        [0., 1.]], dtype=float32)

# %%
pyplot.imshow(Image.fromarray(X_test[0]))
pyplot.show()

# %%
pyplot.imshow(Image.fromarray(X_test[1]))
pyplot.show()

# %%
pyplot.imshow(Image.fromarray(X_test[2]))
pyplot.show()

# %%
pyplot.imshow(Image.fromarray(X_test[3]))
pyplot.show()
